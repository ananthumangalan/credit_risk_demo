# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %% [markdown]
# LOADING DATA

# %%
df_customers = pd.read_csv("customers.csv")
df_loans = pd.read_csv("loans.csv")
df_bureau = pd.read_csv("bureau_data.csv")

# %%
df_customers.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# ...

# %%
df_loans.head()
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
# 3        34940.00  314460           1397600                   6
# 4        90400.00  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# ...

# %%
df_bureau.head()
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
# 3  C00004                        3                          0
# 4  C00005                        4                          2
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
# 3                115                 15         87              5
# 4                120                  0          0              5
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58
# 3                        26
# 4                        10

# %%
df_customers.shape, df_loans.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %% [markdown]
# Merging customer, loans and bureau datasets to form a master datasets

# %%
df = pd.merge(df_customers, df_loans, on = 'cust_id')

# %%
df.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# ...

# %%
df.shape
# Out:
# (50000, 26)

# %%
df = pd.merge(df, df_bureau, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# ...

# %%
df.shape
# Out:
# (50000, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
# ...

# %%
df['default'] = df['default'].astype(int)
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %% [markdown]
# ### shows there is a class imbalance in default

# %% [markdown]
# Train test split before using eda so that there is no data leakagage

# %%
X = df.drop('default', axis='columns')
y = df['default']

X_train, X_test, y_train, y_test = train_test_split(X,y,stratify=y,test_size=0.25,random_state=42)

# %%
X_train.head(3)
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
#
#             city  ... bank_balance_at_application  disbursal_date  \
# 12746  Hyderabad  ...                     4820526      2020-10-31
# 32495     Mumbai  ...                      216697      2022-10-22
# 43675    Chennai  ...                     1383842      2023-12-04
#
#       installment_start_dt number_of_open_accounts number_of_closed_accounts  \
# ...

# %%
y_train.head(3)
# Out:
# 12746    0
# 32495    0
# 43675    0
# Name: default, dtype: int64

# %%
#creating a training dataset
df_train = pd.concat([X_train,y_train],axis="columns")
df_train.head(3)
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
# 43675    Chennai  ...     2023-12-04            2023-12-29
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# ...

# %%
#creating a test dataset
df_test = pd.concat([X_test,y_test],axis="columns")
df_test.head(3)
# Out:
#       cust_id  age gender marital_status employment_status   income  \
# 19205  C19206   36      M        Married     Self-Employed  3728000
# 15514  C15515   43      F         Single     Self-Employed  2493000
# 30367  C30368   30      M        Married     Self-Employed  3114000
#
#        number_of_dependants residence_type  years_at_current_address    city  \
# 19205                     3          Owned                        24  Jaipur
# 15514                     0          Owned                        23   Delhi
# 30367                     4          Owned                        27   Delhi
#
#        ... disbursal_date  installment_start_dt number_of_open_accounts  \
# 19205  ...     2021-06-24            2021-07-23                       2
# 15514  ...     2021-02-09            2021-02-18                       4
# 30367  ...     2022-08-06            2022-08-21                       3
#
#       number_of_closed_accounts total_loan_months  delinquent_months  \
# ...

# %% [markdown]
# ### DATA CLEANING

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37500 entries, 12746 to 37784
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      37500 non-null  object
#  1   age                          37500 non-null  int64
#  2   gender                       37500 non-null  object
#  3   marital_status               37500 non-null  object
#  4   employment_status            37500 non-null  object
#  5   income                       37500 non-null  int64
#  6   number_of_dependants         37500 non-null  int64
#  7   residence_type               37453 non-null  object
#  8   years_at_current_address     37500 non-null  int64
#  9   city                         37500 non-null  object
#  10  state                        37500 non-null  object
#  11  zipcode                      37500 non-null  int64
#  12  loan_id                      37500 non-null  object
# ...

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# ...

# %%
# there is null values in the residence_type columsn

# %%
df_train['residence_type'].unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
df_train['residence_type'].value_counts()
# Out:
# residence_type
# Owned       21133
# Mortgage     8858
# Rented       7462
# Name: count, dtype: int64

# %%
# The mode value is "owned" so it is better fill the null values with "owned"

# %%
mode_residence = df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train.residence_type.fillna(mode_residence,inplace=True)
df_test.residence_type.fillna(mode_residence,inplace=True)
# Out:
# C:\Users\ANANTHU M S\AppData\Local\Temp\ipykernel_10336\3829219026.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train.residence_type.fillna(mode_residence,inplace=True)
# C:\Users\ANANTHU M S\AppData\Local\Temp\ipykernel_10336\3829219026.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented'], dtype=object)

# %%
df_test.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented'], dtype=object)

# %%
df_train.residence_type.value_counts()
# Out:
# residence_type
# Owned       21180
# Mortgage     8858
# Rented       7462
# Name: count, dtype: int64

# %%
df_test.residence_type.value_counts()
# Out:
# residence_type
# Owned       7120
# Mortgage    2961
# Rented      2419
# Name: count, dtype: int64

# %%
df_train.isna().sum()
# Out:
# cust_id                        0
# age                            0
# gender                         0
# marital_status                 0
# employment_status              0
# income                         0
# number_of_dependants           0
# residence_type                 0
# years_at_current_address       0
# city                           0
# state                          0
# zipcode                        0
# loan_id                        0
# loan_purpose                   0
# loan_type                      0
# sanction_amount                0
# loan_amount                    0
# processing_fee                 0
# gst                            0
# net_disbursement               0
# loan_tenure_months             0
# principal_outstanding          0
# bank_balance_at_application    0
# disbursal_date                 0
# installment_start_dt           0
# number_of_open_accounts        0
# number_of_closed_accounts      0
# total_loan_months              0
# ...

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train.describe()
# Out:
#            age      income  number_of_dependants  years_at_current_address  \
# count 37500.00    37500.00              37500.00                  37500.00
# mean     39.54  2633326.16                  1.94                     16.00
# std       9.86  2623780.52                  1.54                      8.92
# min      18.00        0.00                  0.00                      1.00
# 25%      33.00   802000.00                  0.00                      8.00
# 50%      39.00  1885000.00                  2.00                     16.00
# 75%      46.00  3326250.00                  3.00                     24.00
# max      70.00 11999000.00                  5.00                     31.00
#
#         zipcode  sanction_amount  loan_amount  processing_fee        gst  \
# count  37500.00         37500.00     37500.00        37500.00   37500.00
# mean  418866.25       4699691.57   3996067.73        80290.68  719292.19
# ...

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

columns_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %% [markdown]
# ### to find outliers plotting boxplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Select continuous / numerical columns
continuous_cols = df_train.select_dtypes(include=['int64', 'float64']).columns

# Optional: remove target column if present
continuous_cols = continuous_cols.drop('default', errors='ignore')

# Number of columns per row
cols_per_row = 4

# Calculate number of rows needed
rows = math.ceil(len(continuous_cols) / cols_per_row)

# Create subplots
plt.figure(figsize=(20, rows * 4))

for i, col in enumerate(continuous_cols):
    plt.subplot(rows, cols_per_row, i + 1)
    sns.boxplot(y=df_train[col])
    plt.title(col)
    plt.tight_layout()

plt.show()

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplots and histograms show that most financial variables such as loan amount, sanction amount, processing fee, GST, net disbursement, income, and bank balance are right-skewed and contain outliers. These outliers are expected in financial data because some customers may have very high income or large loan amounts. Bureau variables such as total DPD and delinquent months are also right-skewed, indicating that most customers have low delinquency, while a small group has high delayed-payment behavior. These high values should not be blindly removed because they may be important indicators of credit risk. Age and loan tenure appear more stable with fewer extreme values. Columns like zipcode should not be treated as continuous variables even though they are numeric.

# %% [markdown]
# checking the outliers in processing fee

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03][["loan_amount","processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03]
# Out:
#       cust_id  age gender marital_status employment_status   income  \
# 23981  C23982   33      F         Single     Self-Employed  1790000
# 28174  C28175   36      F         Single     Self-Employed  1123000
# 47089  C47090   37      M        Married     Self-Employed  1892000
# 29305  C29306   52      M        Married     Self-Employed  3839000
# 9898   C09899   56      M        Married     Self-Employed  8948000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 23981                     0         Rented                         7
# 28174                     1         Rented                        31
# 47089                     2         Rented                        13
# 29305                     2          Owned                        11
# 9898                      5          Owned                        16
#
#             city  ... disbursal_date  installment_start_dt  \
# 23981    Kolkata  ...     2021-12-15            2022-01-14
# ...

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03][["loan_amount","processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %%
df_train_1 = df_train[df_train.processing_fee/df_train.loan_amount<0.03].copy()
df_train_1.shape
# Out:
# (37488, 33)

# %%
df_test.residence_type.isna().sum()
# Out:
# np.int64(0)

# %%
# Apply same step on test set
df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12497, 33)

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train_1[(df_train_1.gst/df_train_1.loan_amount)>0.2].shape
# Out:
# (0, 33)

# %%
# Rule 2: Net disbursement should not be higher than loan_amount
df_train_1[df_train_1.net_disbursement>df_train_1.loan_amount].shape
# Out:
# (0, 33)

# %% [markdown]
# Analyze categorical columns

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].value_counts())
# Out:
# gender --> gender
# M    22524
# F    14964
# Name: count, dtype: int64
# marital_status --> marital_status
# Married    20603
# Single     16885
# Name: count, dtype: int64
# employment_status --> employment_status
# Self-Employed    24036
# Salaried         13452
# Name: count, dtype: int64
# residence_type --> residence_type
# Owned       21175
# Mortgage     8857
# Rented       7456
# Name: count, dtype: int64
# city --> city
# Mumbai       3828
# Bangalore    3803
# Jaipur       3785
# Ahmedabad    3773
# Delhi        3759
# Kolkata      3738
# Hyderabad    3726
# Pune         3711
# Chennai      3696
# Lucknow      3669
# Name: count, dtype: int64
# state --> state
# Maharashtra      7539
# Karnataka        3803
# Rajasthan        3785
# Gujarat          3773
# Delhi            3759
# West Bengal      3738
# Telangana        3726
# Tamil Nadu       3696
# Uttar Pradesh    3669
# Name: count, dtype: int64
# zipcode --> zipcode
# 400001    3828
# 560001    3803
# 302001    3785
# ...

# %% [markdown]
# Fixing error in loan purpose col

# %%
df_train_1['loan_purpose'] = df_train_1['loan_purpose'].replace('Personaal', 'Personal')
df_train_1['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal', 'Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %% [markdown]
# ### EDA

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %%
#grouping the default people on the bases of age
df_train_1.groupby("default")['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34265.00 39.77 9.88 18.00 33.00 40.00 46.00 70.00
# 1        3223.00 37.12 9.29 18.00 31.00 37.00 44.00 70.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.kdeplot(
    data=df_train,
    x="age",
    hue="default",
    fill=True,
    common_norm=False,
    alpha=0.4
)

plt.title("Age Distribution by Default Status")
plt.xlabel("Age")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# default graph(yellow line shifted towards left indicating that there are people of younger age who default the loan mostly

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_plots = len(columns_continuous)
num_cols = 4
num_rows = (num_plots + num_cols - 1) // num_cols

fig, axes = plt.subplots(
    num_rows,
    num_cols,
    figsize=(5 * num_cols, 5 * num_rows)
)

axes = axes.flatten()

for i, col in enumerate(columns_continuous):
    sns.kdeplot(
        data=df_train,
        x=col,
        hue="default",
        fill=True,
        common_norm=False,
        alpha=0.4,
        ax=axes[i]
    )
    axes[i].set_title(col)

for j in range(num_plots, num_rows * num_cols):
    axes[j].axis("off")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# The KDE plots show that bureau-related variables such as credit_utilization_ratio, total_dpd, and delinquent_months provide much stronger separation between defaulters and non-defaulters than demographic variables such as age, income, and years at current address. This suggests that past credit behavior is more important than basic customer profile information for predicting credit risk.

# %% [markdown]
# ### FEATURE ENGINEERING

# %% [markdown]
# loan to income ratio

# %%
df_train["loan_to_income_ratio"] = df_train["loan_amount"] / df_train["income"]

# %%
df_train[["loan_amount", "income", "loan_to_income_ratio"]].head()
# Out:
#        loan_amount    income  loan_to_income_ratio
# 12746     23442000  11327000                  2.07
# 32495      1149000    715000                  1.61
# 43675     11296000   3195000                  3.54
# 9040       1695000   1500000                  1.13
# 13077       905000   1817000                  0.50

# %%
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'],2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.kdeplot(
    data=df_train,
    x="loan_to_income_ratio",
    hue="default",
    fill=True,
    common_norm=False,
    alpha=0.4
)

plt.title("Loan-to-Income Ratio by Default Status")
plt.xlabel("Loan-to-Income Ratio")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### conclusion = Customers who defaulted generally have a higher loan-to-income ratio than customers who did not default.

# %% [markdown]
# ### Generate deliquency ration

# %% [markdown]
# Delinquency ratio measures how much of a customer’s credit history involved late payment behavior.

# %%
import numpy as np

df_train["delinquency_ratio"] = np.where(
    df_train["total_loan_months"] > 0,
    df_train["delinquent_months"] / df_train["total_loan_months"],
    0
)

# %%
df_test["delinquency_ratio"] = np.where(
    df_test["total_loan_months"] > 0,
    df_test["delinquent_months"] / df_test["total_loan_months"],
    0
)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Create delinquency ratio first
df_train["delinquency_ratio"] = np.where(
    df_train["total_loan_months"] > 0,
    df_train["delinquent_months"] / df_train["total_loan_months"],
    0
)

# KDE plot
plt.figure(figsize=(10, 6))

sns.kdeplot(
    data=df_train,
    x="delinquency_ratio",
    hue="default",
    fill=True,
    common_norm=False,
    alpha=0.4
)

plt.title("Delinquency Ratio by Default Status")
plt.xlabel("Delinquency Ratio")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# The KDE plot shows that non-defaulters are highly concentrated near a delinquency ratio of 0, while defaulters have a wider distribution toward higher delinquency ratios. This indicates that customers with a higher proportion of delinquent months in their credit history are more likely to default. Therefore, delinquency ratio is an important feature for credit risk prediction.

# %%
df_train.head(3)
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
#
#             city  ... number_of_open_accounts  number_of_closed_accounts  \
# 12746  Hyderabad  ...                       4                          2
# 32495     Mumbai  ...                       3                          1
# 43675    Chennai  ...                       1                          1
#
#       total_loan_months delinquent_months total_dpd  enquiry_count  \
# ...

# %% [markdown]
# Average Dpd per deliquency

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Average DPD per delinquent month
df_train["avg_dpd_per_delinquency"] = np.where(
    df_train["delinquent_months"] > 0,
    df_train["total_dpd"] / df_train["delinquent_months"],
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# KDE plot
plt.figure(figsize=(10, 6))

sns.kdeplot(
    data=df_train,
    x="avg_dpd_per_delinquency",
    hue="default",
    fill=True,
    common_norm=False,
    alpha=0.4
)

plt.title("Average DPD per Delinquency by Default Status")
plt.xlabel("Average DPD per Delinquency")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# The KDE plot shows that non-defaulters are highly concentrated near an average DPD per delinquency of 0, while defaulters are more concentrated around higher values, especially between 5 and 6. This indicates that customers with higher average days past due during delinquent months are more likely to default. Therefore, average DPD per delinquency is a useful feature because it captures the severity of delayed repayment behavior.

# %% [markdown]
# ### FEATURE SELECTION

# %%
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %%
df_train.shape, df_train_1.shape, df_train_2.shape
# Out:
# ((37500, 36), (37488, 33), (37488, 31))

# %% [markdown]
# Removing the irrelevant columns

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default'],
#       dtype='object')

# %% [markdown]
# Understanding multicollinearity - VIF Calculation

# %%
X_train = df_train_3.drop('default', axis='columns')
y_train = df_train_3['default']

# %%
#scaling the data using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

cols_to_scale = X_train.select_dtypes(['int64', 'float64']).columns

scaler = MinMaxScaler()

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37488.00              37488.00                  37488.00 37488.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.40                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# ...

# %%
#scaling the test data using the same scaler
X_test = df_test.drop('default', axis='columns')
X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])
y_test = df_test['default']
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12497.00              12497.00                  12497.00 12497.00
# mean      0.42                  0.38                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
# c:\Users\ANANTHU M S\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.62
# 1          number_of_dependants   2.72
# 2      years_at_current_address   3.36
# 3                       zipcode   3.73
# 4               sanction_amount 100.61
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   3.93
# 9         principal_outstanding  15.21
# 10  bank_balance_at_application   9.28
# 11      number_of_open_accounts   3.98
# 12    number_of_closed_accounts   2.36
# 13                enquiry_count   6.33
# 14     credit_utilization_ratio   2.90

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio'],
#       dtype='object')

# %%
calculate_vif(X_train_1[numeric_columns])
# Out:
#                         Column  VIF
# 0                          age 5.23
# 1         number_of_dependants 2.72
# 2     years_at_current_address 3.36
# 3                      zipcode 3.72
# 4           loan_tenure_months 3.18
# 5  bank_balance_at_application 1.80
# 6      number_of_open_accounts 3.95
# 7    number_of_closed_accounts 2.36
# 8                enquiry_count 6.33
# 9     credit_utilization_ratio 2.90

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns
corr_matrix = df_train_3.select_dtypes(include=["int64", "float64", "bool"]).corr()

plt.figure(figsize=(18, 12))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Matrix for df_train_3")
plt.show()

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
